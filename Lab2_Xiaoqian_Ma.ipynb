# %% [markdown]
# <a href="https://colab.research.google.com/github/IreneMXQ/ProgrammingAssignment2/blob/master/Lab2_Xiaoqian_Ma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.path_graph(5)
nx.draw(G, with_labels=True)
plt.show()

# %%
print("radius: %d" % nx.radius(G))
print("diameter: %d" % nx.diameter(G))
print("eccentricity: %s" % nx.eccentricity(G))
print("center: %s" % nx.center(G))
print("periphery: %s" % nx.periphery(G))
print("density: %s" % nx.density(G))
# Out:
# radius: 2
# diameter: 4
# eccentricity: {0: 4, 1: 3, 2: 2, 3: 3, 4: 4}
# center: [2]
# periphery: [0, 4]
# density: 0.4

# %%
print("Betweenness")
b = nx.betweenness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, b[v]))

print("Degree centrality")
d = nx.degree_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, d[v]))

print("Closeness centrality")
c = nx.closeness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, c[v]))

print("Eigenvector centrality")
centrality = nx.eigenvector_centrality(G)
sorted((v, '{:0.2f}'.format(c)) for v, c in centrality.items())
# Out:
# Betweenness
# 00 0.000
# 01 0.500
# 02 0.667
# 03 0.500
# 04 0.000
# Degree centrality
# 00 0.250
# 01 0.500
# 02 0.500
# 03 0.500
# 04 0.250
# Closeness centrality
# 00 0.400
# 01 0.571
# 02 0.667
# 03 0.571
# 04 0.400
# Eigenvector centrality
# [(0, '0.29'), (1, '0.50'), (2, '0.58'), (3, '0.50'), (4, '0.29')]

# %% [markdown]
# Q1: Use one sentence each to briefly describe the characteristics of each graph type (its shape, edges, etc..)
# Answer:
# shape: line (linear);
# edge: 4

# %%
G = nx.cycle_graph(5)
nx.draw(G, node_color='green', with_labels=True)
plt.show()

# %% [markdown]
# Q1: Use one sentence each to briefly describe the characteristics of each graph type (its shape, edges, etc..)
# Answer:
# shape:
# edge:

# %%
G = nx.complete_graph(5)
nx.draw(G, node_color='#A0CBE2', edge_color='red', width=2, with_labels=False)
plt.show()

# %% [markdown]
# Q1: Use one sentence each to briefly describe the characteristics of each graph type (its shape, edges, etc..)
# Answer:
# shape:
# edge:

# %%
G = nx.star_graph(5)
pos=nx.spring_layout(G)
nx.draw(G, pos, with_labels=True)
plt.show()

# %% [markdown]
# Q1: Use one sentence each to briefly describe the characteristics of each graph type (its shape, edges, etc..)
# Answer:
# shape:
# edge:

# %%
G = nx.lollipop_graph(3,2)
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# Q1: Use one sentence each to briefly describe the characteristics of each graph type (its shape, edges, etc..)
# Answer:
# shape:
# edge:

# %%
list(nx.connected_components(G))
# Out:
# [{0, 1, 2, 3, 4}]

# %%
nx.clustering(G)
# Out:
# {0: 1.0, 1: 1.0, 2: 0.3333333333333333, 3: 0, 4: 0}

# %% [markdown]
# Q2: How many connected components are there in the graph? What are they?
# Answer:only 1, 0 to 4, 5 nodes

# %% [markdown]
# Q3: Which nodes have the highest local clustering coefficient? Explain (from the definition) why they have high clustering coefficient.
# Answer: node0 and node1, because for node0 and node1,  all their friends are connected (node0 connects to node1 and node2, and there only one potential connections, node1 with node2, and the connection between node1 and node2 is observed)

# %%
print("Betweenness")
b = nx.betweenness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, b[v]))

print("Degree centrality")
d = nx.degree_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, d[v]))

print("Closeness centrality")
c = nx.closeness_centrality(G)
for v in G.nodes():
    print("%0.2d %5.3f" % (v, c[v]))

print("Eigenvector centrality")
centrality = nx.eigenvector_centrality(G)
sorted((v, '{:0.2f}'.format(c)) for v, c in centrality.items())
# Out:
# Betweenness
# 00 0.000
# 01 0.000
# 02 0.667
# 03 0.500
# 04 0.000
# Degree centrality
# 00 0.500
# 01 0.500
# 02 0.750
# 03 0.500
# 04 0.250
# Closeness centrality
# 00 0.571
# 01 0.571
# 02 0.800
# 03 0.667
# 04 0.444
# Eigenvector centrality
# [(0, '0.50'), (1, '0.50'), (2, '0.60'), (3, '0.34'), (4, '0.15')]

# %% [markdown]
# Q4: Which node(s) has the highest betweenness, degree, closeness, eigenvector centrality? Explain using the definitions and graph structures.
# Answer: 1) node2 has the highest betweenness centrality.
# Explanation: the node2 is the node which has the most number of geodesics passing through and has connections to networks on both sides.

# %%
pathlengths = []
print("source vertex {target:length, }")
for v in G.nodes():
    spl = dict(nx.single_source_shortest_path_length(G, v))
    print('{} {} '.format(v, spl))
    for p in spl:
        pathlengths.append(spl[p])
print('')
print("average shortest path length %s" % (sum(pathlengths) / len(pathlengths)))

dist = {}
for p in pathlengths:
    if p in dist:
        dist[p] += 1
    else:
        dist[p] = 1
print('')
print("length #paths")
verts = dist.keys()
for d in sorted(verts):
    print('%s %d' % (d, dist[d]))
# Out:
# source vertex {target:length, }
# 0 {0: 0, 1: 1, 2: 1, 3: 2, 4: 3}
# 1 {1: 0, 0: 1, 2: 1, 3: 2, 4: 3}
# 2 {2: 0, 0: 1, 1: 1, 3: 1, 4: 2}
# 3 {3: 0, 2: 1, 4: 1, 0: 2, 1: 2}
# 4 {4: 0, 3: 1, 2: 2, 0: 3, 1: 3}
#
# average shortest path length 1.36
#
# length #paths
# 0 5
# 1 10
# 2 6
# 3 4

# %%
mapping = {0: 'a', 1: 'b', 2: 'c', 3: 'd', 4: 'e'}
H = nx.relabel_nodes(G, mapping)
nx.draw(H, with_labels=True)
plt.show()
